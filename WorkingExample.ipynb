# %%
import pandas as pd

# %% [markdown]
# ## Import Woodwork (to hit decorator)

# %%
import woodwork as ww

# %% [markdown]
# ## Create DataFrame

# %%
# df = ww.demo.load_retail(nrows=100, return_dataframe=True)

df = pd.read_csv('retail_data.csv', nrows=100)
df.head(5)
# Out:
#    Unnamed: 0  order_product_id  order_id product_id  \
# 0           0                 0    536365     85123A
# 1           1                 1    536365      71053
# 2           2                 2    536365     84406B
# 3           3                 3    536365     84029G
# 4           4                 4    536365     84029E
#
#                            description  quantity           order_date  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6  2010-12-01 08:26:00
# 1                  WHITE METAL LANTERN         6  2010-12-01 08:26:00
# 2       CREAM CUPID HEARTS COAT HANGER         8  2010-12-01 08:26:00
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6  2010-12-01 08:26:00
# 4       RED WOOLLY HOTTIE WHITE HEART.         6  2010-12-01 08:26:00
#
#    unit_price customer_name         country   total  cancelled
# 0      4.2075  Andrea Brown  United Kingdom  25.245      False
# 1      5.5935  Andrea Brown  United Kingdom  33.561      False
# 2      4.5375  Andrea Brown  United Kingdom  36.300      False
# 3      5.5935  Andrea Brown  United Kingdom  33.561      False
# 4      5.5935  Andrea Brown  United Kingdom  33.561      False

# %% [markdown]
# ### DataFrame Dtypes

# %%
df.dtypes
# Out:
# Unnamed: 0            int64
# order_product_id      int64
# order_id              int64
# product_id           object
# description          object
# quantity              int64
# order_date           object
# unit_price          float64
# customer_name        object
# country              object
# total               float64
# cancelled              bool
# dtype: object

# %% [markdown]
# ## Use the Woodwork Accessor
#
# The point of the accessor is to have a dataframe that we can work with as normal while also having a the information from a DataTable available. The way this works is that each DataFrame object will have a DataTableAccessor available to it. This means that if you reassign the dataframe, you lose your typing information from the DataTable.
#
# We're going to walk through some use cases, but first we have to know how to set up the DataTable accessor according to our preferences.
#
# We can look at the DataTableAccessor as follows:

# %%
df.ww
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Physical Type</th>
#       <th>Logical Type</th>
#       <th>Semantic Tag(s)</th>
#     </tr>
#     <tr>
#       <th>Data Column</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Unnamed: 0</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>order_product_id</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>order_id</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>product_id</th>
#       <td>category</td>
#       <td>Categorical</td>
#       <td>['category']</td>
#     </tr>
#     <tr>
#       <th>description</th>
#       <td>string</td>
#       <td>NaturalLanguage</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>quantity</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>order_date</th>
#       <td>datetime64[ns]</td>
#       <td>Datetime</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>unit_price</th>
#       <td>float64</td>
#       <td>Double</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>customer_name</th>
#       <td>string</td>
#       <td>NaturalLanguage</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>country</th>
#       <td>string</td>
#       <td>NaturalLanguage</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>total</th>
#       <td>float64</td>
#       <td>Double</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>cancelled</th>
#       <td>boolean</td>
#       <td>Boolean</td>
#       <td>[]</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Notice how this is the repr of a DataTable! The above result is the same as if you did `DataTable(df)`. There are no extra parameters provided to the DataTable, so we just have the automatically inferred Logical Types and semantic tags. You can access all methods and properties on a DataTable just like this.
#
# Notice that the dtypes of the dataframe have changed to match those of the DataTable Accessor.

# %%
df.dtypes
# Out:
# Unnamed: 0                   Int64
# order_product_id             Int64
# order_id                     Int64
# product_id                category
# description                 string
# quantity                     Int64
# order_date          datetime64[ns]
# unit_price                 float64
# customer_name               string
# country                     string
# total                      float64
# cancelled                  boolean
# dtype: object

# %% [markdown]
# Likely, we'll want to set our own Logical Types or semantic tags. We can do that using any of DataTable's methods!
#
# ## Set DataTable attributes via DataTable methods
#
# Notice how we need to set `df.ww.dt` any time a method returns a new DataTable. We're currently pulling methods directly from DataTable, which means that any DataTable attribute is available to us, but we have to follow its rules and update the `dt` on the accessor.
#
# ### Set Semantic Tags (after reading DataFrame)

# %%
df.ww.dt = df.ww.add_semantic_tags({'order_date': 'tag_1'})
df.ww.types
# Out:
#                    Physical Type     Logical Type Semantic Tag(s)
# Data Column
# Unnamed: 0                 Int64          Integer     ['numeric']
# order_product_id           Int64          Integer     ['numeric']
# order_id                   Int64          Integer     ['numeric']
# product_id              category      Categorical    ['category']
# description               string  NaturalLanguage              []
# quantity                   Int64          Integer     ['numeric']
# order_date        datetime64[ns]         Datetime       ['tag_1']
# unit_price               float64           Double     ['numeric']
# customer_name             string  NaturalLanguage              []
# country                   string  NaturalLanguage              []
# total                    float64           Double     ['numeric']
# cancelled                boolean          Boolean              []

# %% [markdown]
# ### Set the time index (after reading DataFrame)

# %%
df.ww.dt = df.ww.set_time_index('order_date')
df.ww
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Physical Type</th>
#       <th>Logical Type</th>
#       <th>Semantic Tag(s)</th>
#     </tr>
#     <tr>
#       <th>Data Column</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Unnamed: 0</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>order_product_id</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>order_id</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>product_id</th>
#       <td>category</td>
#       <td>Categorical</td>
#       <td>['category']</td>
#     </tr>
#     <tr>
#       <th>description</th>
#       <td>string</td>
#       <td>NaturalLanguage</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>quantity</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>order_date</th>
#       <td>datetime64[ns]</td>
#       <td>Datetime</td>
#       <td>['time_index', 'tag_1']</td>
#     </tr>
#     <tr>
#       <th>unit_price</th>
#       <td>float64</td>
#       <td>Double</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>customer_name</th>
#       <td>string</td>
#       <td>NaturalLanguage</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>country</th>
#       <td>string</td>
#       <td>NaturalLanguage</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>total</th>
#       <td>float64</td>
#       <td>Double</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>cancelled</th>
#       <td>boolean</td>
#       <td>Boolean</td>
#       <td>[]</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Of course, it can be tedious to set each element of the DataTable individually, so the DataTable accessor provides an `init` method, which lets us pass the parameters we'd pass to DataTable.
#
# We'll reread the csv to start from ground zero with the DataTable.
#
# ### Set Initial DataTable Attributes (index, time index, name, logical types)

# %%
df = pd.read_csv('retail_data.csv', nrows=100)
df.ww.init(name='retail_data',
           time_index='order_date', 
           logical_types={'customer_name':'FullName', 'country':'CountryCode'}, 
           index='order_product_id')
df.ww
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Physical Type</th>
#       <th>Logical Type</th>
#       <th>Semantic Tag(s)</th>
#     </tr>
#     <tr>
#       <th>Data Column</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Unnamed: 0</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>order_product_id</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['index']</td>
#     </tr>
#     <tr>
#       <th>order_id</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>product_id</th>
#       <td>category</td>
#       <td>Categorical</td>
#       <td>['category']</td>
#     </tr>
#     <tr>
#       <th>description</th>
#       <td>string</td>
#       <td>NaturalLanguage</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>quantity</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>order_date</th>
#       <td>datetime64[ns]</td>
#       <td>Datetime</td>
#       <td>['time_index']</td>
#     </tr>
#     <tr>
#       <th>unit_price</th>
#       <td>float64</td>
#       <td>Double</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>customer_name</th>
#       <td>string</td>
#       <td>FullName</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>country</th>
#       <td>category</td>
#       <td>CountryCode</td>
#       <td>['category']</td>
#     </tr>
#     <tr>
#       <th>total</th>
#       <td>float64</td>
#       <td>Double</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>cancelled</th>
#       <td>boolean</td>
#       <td>Boolean</td>
#       <td>[]</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# If we look at the dtypes on the dataframe, we'll see the dtypes of `quantity` and `country` have changed as well!

# %%
df.dtypes
# Out:
# Unnamed: 0                   Int64
# order_product_id             Int64
# order_id                     Int64
# product_id                category
# description                 string
# quantity                     Int64
# order_date          datetime64[ns]
# unit_price                 float64
# customer_name               string
# country                   category
# total                      float64
# cancelled                  boolean
# dtype: object

# %% [markdown]
# ## Working with Your DataFrame + DataTable Accessor
#
# ### Select Based on Tags / Logical Types
#
# Now that we have our types set, let's use them! Say we want to a DataFrame that only has categorical, natural language, and numeric. We'll use `select` for that, giving us an updated DataTable with just the relevant columns.
#
# But, our actual goal here is to get the DataFrame. This is how we can do that:

# %%
selected_dt = df.ww.select(['FullName', 'CountryCode'])
selected_dt
# Out:
#               Physical Type Logical Type Semantic Tag(s)
# Data Column
# customer_name        string     FullName              []
# country            category  CountryCode    ['category']

# %% [markdown]
# Now we can easily get that DataFrame, but we've lost some of our DataTable typing info.

# %%
df = selected_dt.to_dataframe()
df.ww
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Physical Type</th>
#       <th>Logical Type</th>
#       <th>Semantic Tag(s)</th>
#     </tr>
#     <tr>
#       <th>Data Column</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>customer_name</th>
#       <td>string</td>
#       <td>NaturalLanguage</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>country</th>
#       <td>category</td>
#       <td>Categorical</td>
#       <td>['category']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The good news is that our DataTable will match our dataframe perfectly, so we can easiy fix that:

# %%
df.ww.dt = selected_dt
df.ww
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Physical Type</th>
#       <th>Logical Type</th>
#       <th>Semantic Tag(s)</th>
#     </tr>
#     <tr>
#       <th>Data Column</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>customer_name</th>
#       <td>string</td>
#       <td>FullName</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>country</th>
#       <td>category</td>
#       <td>CountryCode</td>
#       <td>['category']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Update your DataFrame
#
# In the example above, we performed an action on a DataTable and had to get out the DataFrame and update it to keep the typing info up to date. The converse is also possible.
#
# If we want to change a DataFrame--say via `sample`--we will get a new DataFrame devoid of any typing info, so we'll need to update it. Let's see how we can do that:

# %%
df = pd.read_csv('retail_data.csv', nrows=100)
df.ww.init(name='retail_data',
           time_index='order_date', 
           logical_types={'customer_name':'FullName', 'country':'CountryCode'}, 
           index='order_product_id')
original_dt = df.ww.dt
df.ww
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Physical Type</th>
#       <th>Logical Type</th>
#       <th>Semantic Tag(s)</th>
#     </tr>
#     <tr>
#       <th>Data Column</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Unnamed: 0</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>order_product_id</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['index']</td>
#     </tr>
#     <tr>
#       <th>order_id</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>product_id</th>
#       <td>category</td>
#       <td>Categorical</td>
#       <td>['category']</td>
#     </tr>
#     <tr>
#       <th>description</th>
#       <td>string</td>
#       <td>NaturalLanguage</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>quantity</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>order_date</th>
#       <td>datetime64[ns]</td>
#       <td>Datetime</td>
#       <td>['time_index']</td>
#     </tr>
#     <tr>
#       <th>unit_price</th>
#       <td>float64</td>
#       <td>Double</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>customer_name</th>
#       <td>string</td>
#       <td>FullName</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>country</th>
#       <td>category</td>
#       <td>CountryCode</td>
#       <td>['category']</td>
#     </tr>
#     <tr>
#       <th>total</th>
#       <td>float64</td>
#       <td>Double</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>cancelled</th>
#       <td>boolean</td>
#       <td>Boolean</td>
#       <td>[]</td>
#     </tr>
#   </tbody>
# </table>

# %%
df = df.sample(50)
df.ww
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Physical Type</th>
#       <th>Logical Type</th>
#       <th>Semantic Tag(s)</th>
#     </tr>
#     <tr>
#       <th>Data Column</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Unnamed: 0</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>order_product_id</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>order_id</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>product_id</th>
#       <td>category</td>
#       <td>Categorical</td>
#       <td>['category']</td>
#     </tr>
#     <tr>
#       <th>description</th>
#       <td>string</td>
#       <td>NaturalLanguage</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>quantity</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>order_date</th>
#       <td>datetime64[ns]</td>
#       <td>Datetime</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>unit_price</th>
#       <td>float64</td>
#       <td>Double</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>customer_name</th>
#       <td>string</td>
#       <td>NaturalLanguage</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>country</th>
#       <td>category</td>
#       <td>Categorical</td>
#       <td>['category']</td>
#     </tr>
#     <tr>
#       <th>total</th>
#       <td>float64</td>
#       <td>Double</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>cancelled</th>
#       <td>boolean</td>
#       <td>Boolean</td>
#       <td>[]</td>
#     </tr>
#   </tbody>
# </table>

# %%
original_dt.update_dataframe(df)
df.ww.dt = original_dt
df.ww
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Physical Type</th>
#       <th>Logical Type</th>
#       <th>Semantic Tag(s)</th>
#     </tr>
#     <tr>
#       <th>Data Column</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Unnamed: 0</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>order_product_id</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['index']</td>
#     </tr>
#     <tr>
#       <th>order_id</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>product_id</th>
#       <td>category</td>
#       <td>Categorical</td>
#       <td>['category']</td>
#     </tr>
#     <tr>
#       <th>description</th>
#       <td>string</td>
#       <td>NaturalLanguage</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>quantity</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>order_date</th>
#       <td>datetime64[ns]</td>
#       <td>Datetime</td>
#       <td>['time_index']</td>
#     </tr>
#     <tr>
#       <th>unit_price</th>
#       <td>float64</td>
#       <td>Double</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>customer_name</th>
#       <td>string</td>
#       <td>FullName</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>country</th>
#       <td>category</td>
#       <td>CountryCode</td>
#       <td>['category']</td>
#     </tr>
#     <tr>
#       <th>total</th>
#       <td>float64</td>
#       <td>Double</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>cancelled</th>
#       <td>boolean</td>
#       <td>Boolean</td>
#       <td>[]</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# These two examples above highlight the benefits of keeping your DataFrame and DataTable in sync. This is all currently being done with very minimal code written outside of what currently exists, but it's likely that there'll be good ways to simplify this process.
#
# Let's work through some more use cases that might come up.

# %% [markdown]
# ### Using iloc
#
# iloc exists both on DataFrames and DataTables. Let's look at two different ways of using iloc to get a new Dataframe with the correct typing info.

# %%
# DataFrame.iloc
df = pd.read_csv('retail_data.csv', nrows=100)
df.ww.init(name='retail_data',
           time_index='order_date', 
           logical_types={'customer_name':'FullName', 'country':'CountryCode'}, 
           index='order_product_id')

original_dt = df.ww.dt
df = df.iloc[:,-4:]
df.ww.dt = original_dt[list(df.columns)]
df.ww
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Physical Type</th>
#       <th>Logical Type</th>
#       <th>Semantic Tag(s)</th>
#     </tr>
#     <tr>
#       <th>Data Column</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>customer_name</th>
#       <td>string</td>
#       <td>FullName</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>country</th>
#       <td>category</td>
#       <td>CountryCode</td>
#       <td>['category']</td>
#     </tr>
#     <tr>
#       <th>total</th>
#       <td>float64</td>
#       <td>Double</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>cancelled</th>
#       <td>boolean</td>
#       <td>Boolean</td>
#       <td>[]</td>
#     </tr>
#   </tbody>
# </table>

# %%
# DataTable.iloc
df = pd.read_csv('retail_data.csv', nrows=100)
df.ww.init(name='retail_data',
           time_index='order_date', 
           logical_types={'customer_name':'FullName', 'country':'CountryCode'}, 
           index='order_product_id')

updated_dt = df.ww.iloc[:,-4:]
df = updated_dt.to_dataframe()
df.ww.dt = updated_dt
df.ww
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Physical Type</th>
#       <th>Logical Type</th>
#       <th>Semantic Tag(s)</th>
#     </tr>
#     <tr>
#       <th>Data Column</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>customer_name</th>
#       <td>string</td>
#       <td>FullName</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>country</th>
#       <td>category</td>
#       <td>CountryCode</td>
#       <td>['category']</td>
#     </tr>
#     <tr>
#       <th>total</th>
#       <td>float64</td>
#       <td>Double</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>cancelled</th>
#       <td>boolean</td>
#       <td>Boolean</td>
#       <td>[]</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## In Place Changes
#
# We've looked at various DataTable methods that create a new DataTable, but let's look at one that mutates the DataTable itself.
#
# Note: Any of this behavior can be changed based on input!
#
# ### Pop a column

# %%
# DataFrame.pop
df = pd.read_csv('retail_data.csv', nrows=100)
df.ww.init(name='retail_data',
           time_index='order_date', 
           logical_types={'customer_name':'FullName', 'country':'CountryCode'}, 
           index='order_product_id')

# Won't remove from DataTable
series = df.pop('cancelled')
assert 'cancelled' not in df.columns
assert 'cancelled' in df.ww.columns

df.ww.dt = df.ww.dt[list(df.columns)]
assert 'cancelled' not in df.columns
assert 'cancelled' not in df.ww.columns
df.ww #still has relevant types because it was all done in place
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Physical Type</th>
#       <th>Logical Type</th>
#       <th>Semantic Tag(s)</th>
#     </tr>
#     <tr>
#       <th>Data Column</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Unnamed: 0</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>order_product_id</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['index']</td>
#     </tr>
#     <tr>
#       <th>order_id</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>product_id</th>
#       <td>category</td>
#       <td>Categorical</td>
#       <td>['category']</td>
#     </tr>
#     <tr>
#       <th>description</th>
#       <td>string</td>
#       <td>NaturalLanguage</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>quantity</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>order_date</th>
#       <td>datetime64[ns]</td>
#       <td>Datetime</td>
#       <td>['time_index']</td>
#     </tr>
#     <tr>
#       <th>unit_price</th>
#       <td>float64</td>
#       <td>Double</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>customer_name</th>
#       <td>string</td>
#       <td>FullName</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>country</th>
#       <td>category</td>
#       <td>CountryCode</td>
#       <td>['category']</td>
#     </tr>
#     <tr>
#       <th>total</th>
#       <td>float64</td>
#       <td>Double</td>
#       <td>['numeric']</td>
#     </tr>
#   </tbody>
# </table>

# %%
# DataTable.pop
df = pd.read_csv('retail_data.csv', nrows=100)
df.ww.init(name='retail_data',
           time_index='order_date', 
           logical_types={'customer_name':'FullName', 'country':'CountryCode'}, 
           index='order_product_id')

# Won't remove from DataFrame
datacolumn = df.ww.pop('cancelled')
assert 'cancelled' in df.columns
assert 'cancelled' not in df.ww.columns

df.drop('cancelled',axis=1, inplace=True)
assert 'cancelled' not in df.columns
assert 'cancelled' not in df.ww.columns

df.ww
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Physical Type</th>
#       <th>Logical Type</th>
#       <th>Semantic Tag(s)</th>
#     </tr>
#     <tr>
#       <th>Data Column</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Unnamed: 0</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>order_product_id</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['index']</td>
#     </tr>
#     <tr>
#       <th>order_id</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>product_id</th>
#       <td>category</td>
#       <td>Categorical</td>
#       <td>['category']</td>
#     </tr>
#     <tr>
#       <th>description</th>
#       <td>string</td>
#       <td>NaturalLanguage</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>quantity</th>
#       <td>Int64</td>
#       <td>Integer</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>order_date</th>
#       <td>datetime64[ns]</td>
#       <td>Datetime</td>
#       <td>['time_index']</td>
#     </tr>
#     <tr>
#       <th>unit_price</th>
#       <td>float64</td>
#       <td>Double</td>
#       <td>['numeric']</td>
#     </tr>
#     <tr>
#       <th>customer_name</th>
#       <td>string</td>
#       <td>FullName</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>country</th>
#       <td>category</td>
#       <td>CountryCode</td>
#       <td>['category']</td>
#     </tr>
#     <tr>
#       <th>total</th>
#       <td>float64</td>
#       <td>Double</td>
#       <td>['numeric']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Other DataTable Functionality
#
# ### Serialization
# We can serialize!

# %%
df.ww.to_csv('test')

# %%
import os
print(os.listdir('test'))
print(os.listdir('test/data'))
# Out:
# ['table_description.json', 'data']
# ['retail_data.csv', 'data.csv']

# %% [markdown]
# ### Statistical Insights

# %%
df = pd.read_csv('retail_data.csv', nrows=100)
df.ww.init(name='retail_data',
           time_index='order_date', 
           logical_types={'customer_name':'FullName', 'country':'CountryCode'}, 
           index='order_product_id')

df.ww.describe()
# Out:
#                 Unnamed: 0   order_id   product_id  \
# physical_type        Int64      Int64     category
# logical_type       Integer    Integer  Categorical
# semantic_tags    {numeric}  {numeric}   {category}
# count                  100        100          100
# nunique                100         14           73
# nan_count                0          0            0
# mean                  49.5     536372          NaN
# mode                     0     536370        21730
# std                29.0115    4.04184          NaN
# min                      0     536365          NaN
# first_quartile       24.75     536369          NaN
# second_quartile       49.5     536373          NaN
# third_quartile       74.25     536375          NaN
# max                     99     536378          NaN
# num_true               NaN        NaN          NaN
# num_false              NaN        NaN          NaN
#
#                                     description   quantity  \
# physical_type                            string      Int64
# logical_type                    NaturalLanguage    Integer
# semantic_tags                                {}  {numeric}
# count                                       100        100
# nunique                                     NaN         16
# nan_count                                     0          0
# mean                                        NaN       13.1
# mode             CREAM CUPID HEARTS COAT HANGER          6
# std                                         NaN    16.8879
# min                                         NaN          2
# first_quartile                              NaN          6
# second_quartile                             NaN          6
# third_quartile                              NaN       13.5
# max                                         NaN        120
# num_true                                    NaN        NaN
# num_false                                   NaN        NaN
#
#                                     order_date unit_price customer_name  \
# physical_type                   datetime64[ns]    float64        string
# logical_type                          Datetime     Double      FullName
# semantic_tags                     {time_index}  {numeric}            {}
# count                                      100        100           100
# nunique                                     12         26           NaN
# nan_count                                    0          0             0
# mean             2010-12-01 09:01:37.199999744    5.40606           NaN
# mode                       2010-12-01 08:45:00     4.2075  Andrea Brown
# std                                        NaN    4.30838           NaN
# min                        2010-12-01 08:26:00      0.693           NaN
# first_quartile                             NaN      2.772           NaN
# second_quartile                            NaN     4.3725           NaN
# third_quartile                             NaN     7.0125           NaN
# max                        2010-12-01 09:37:00       29.7           NaN
# num_true                                   NaN        NaN           NaN
# num_false                                  NaN        NaN           NaN
#
#                         country      total cancelled
# physical_type          category    float64   boolean
# logical_type        CountryCode     Double   Boolean
# semantic_tags        {category}  {numeric}        {}
# count                       100        100       100
# nunique                       2         41       NaN
# nan_count                     0          0         0
# mean                        NaN    51.5283       NaN
# mode             United Kingdom     25.245     False
# std                         NaN    74.3198       NaN
# min                         NaN     10.494       NaN
# first_quartile              NaN      20.79       NaN
# second_quartile             NaN     32.175       NaN
# third_quartile              NaN     49.005       NaN
# max                         NaN     578.16       NaN
# num_true                    NaN        NaN         0
# num_false                   NaN        NaN       100

# %%
df.ww.value_counts()
# Out:
# {'product_id': [{'value': '84029E', 'count': 3},
#   {'value': '22752', 'count': 3},
#   {'value': '71053', 'count': 3},
#   {'value': '22632', 'count': 3},
#   {'value': '84029G', 'count': 3},
#   {'value': '84406B', 'count': 3},
#   {'value': '85123A', 'count': 3},
#   {'value': '21730', 'count': 3},
#   {'value': '22633', 'count': 3},
#   {'value': '21068', 'count': 2}],
#  'country': [{'value': 'United Kingdom', 'count': 80},
#   {'value': 'France', 'count': 20}]}

# %% [markdown]
# ## Current Problems
#
#
# ### Problem 1 -

# %%
df['cancelled'] = df['cancelled'].astype('int')

# %%
df.head(2)
# Out:
#    Unnamed: 0  order_product_id  order_id product_id  \
# 0           0                 0    536365     85123A
# 1           1                 1    536365      71053
#
#                           description  quantity          order_date  \
# 0  WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1                 WHITE METAL LANTERN         6 2010-12-01 08:26:00
#
#    unit_price customer_name         country   total  cancelled
# 0      4.2075  Andrea Brown  United Kingdom  25.245          0
# 1      5.5935  Andrea Brown  United Kingdom  33.561          0

# %%
df.dtypes
# Out:
# Unnamed: 0                   Int64
# order_product_id             Int64
# order_id                     Int64
# product_id                category
# description                 string
# quantity                     Int64
# order_date          datetime64[ns]
# unit_price                 float64
# customer_name               string
# country                   category
# total                      float64
# cancelled                    int64
# dtype: object

# %%
df.ww.select('boolean')
# Out:
#             Physical Type Logical Type Semantic Tag(s)
# Data Column
# cancelled         boolean      Boolean              []

# %%
df.ww.to_dataframe().head(2)
# Out:
#    Unnamed: 0  order_product_id  order_id product_id  \
# 0           0                 0    536365     85123A
# 1           1                 1    536365      71053
#
#                           description  quantity          order_date  \
# 0  WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1                 WHITE METAL LANTERN         6 2010-12-01 08:26:00
#
#    unit_price customer_name         country   total  cancelled
# 0      4.2075  Andrea Brown  United Kingdom  25.245      False
# 1      5.5935  Andrea Brown  United Kingdom  33.561      False

# %% [markdown]
# # To Do - Add Util Functions

# %% [markdown]
# ```python
# def describe(dataframe)
#     """
#         dataframe (pd.DataFrame): DataFrame with woodwork init
#     """
# ```

# %% [markdown]
# ### End user Usage
#
# ```python
# from woodwork import describe
#
# dataframe_described = describe(df)
# ```
