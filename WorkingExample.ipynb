# %%
import pandas as pd

# %% [markdown]
# ## Import Accessor

# %%
import woodwork.accessor

# %% [markdown]
# ## Create DataFrame

# %%
df = pd.read_csv('retail_data.csv', nrows=100)

# %%
df
# Out:
#     order_id product_id                          description  quantity  \
# 0     536588      22666      RECIPE BOX PANTRY YELLOW DESIGN        12
# 1     536732      22910    PAPER CHAIN KIT VINTAGE CHRISTMAS         6
# 2     536733      84375        SET OF 20 KIDS COOKIE CUTTERS        12
# 3     536403      22867              HAND WARMER BIRD DESIGN        96
# 4     536753      22632            HAND WARMER RED POLKA DOT         6
# ..       ...        ...                                  ...       ...
# 95    536582      22771  CLEAR DRAWER KNOB ACRYLIC EDWARDIAN        24
# 96    536749      22371         AIRLINE BAG VINTAGE TOKYO 78         1
# 97    536566      22771  CLEAR DRAWER KNOB ACRYLIC EDWARDIAN        10
# 98    536597     35271S                 GOLD PRINT PAPER BAG        14
# 99    536624      22925        BLUE GIANT GARDEN THERMOMETER         2
#
#              order_date  unit_price      customer_name         country  \
# 0   2010-12-01 16:49:00      4.8675     Emily Carrillo  United Kingdom
# 1   2010-12-02 12:47:00      4.8675         Tyler Rose  United Kingdom
# 2   2010-12-02 12:50:00      3.4650  Jacqueline Garcia  United Kingdom
# 3   2010-12-01 11:27:00      3.0525       Shawn Carson     Netherlands
# 4   2010-12-02 14:07:00      3.0525       Andrea Brown  United Kingdom
# ..                  ...         ...                ...             ...
# 95  2010-12-01 16:21:00      2.0625       Rachel Short  United Kingdom
# 96  2010-12-02 13:49:00      7.0125  Christian Jackson  United Kingdom
# 97  2010-12-01 15:21:00      2.0625        Jared Walsh  United Kingdom
# 98  2010-12-01 17:35:00      0.3135      Samantha Dunn  United Kingdom
# 99  2010-12-02 10:45:00      9.8175      Colleen Davis  United Kingdom
#
#        total  cancelled
# 0    58.4100      False
# 1    29.2050      False
# 2    41.5800      False
# 3   293.0400      False
# 4    18.3150      False
# ..       ...        ...
# 95   49.5000      False
# 96    7.0125      False
# 97   20.6250      False
# 98    4.3890      False
# 99   19.6350      False
#
# [100 rows x 10 columns]

# %%
df.dtypes
# Out:
# order_id           int64
# product_id        object
# description       object
# quantity           int64
# order_date        object
# unit_price       float64
# customer_name     object
# country           object
# total            float64
# cancelled           bool
# dtype: object

# %%
df.ww.types
# Out:
#                 Physical Type     Logical Type Semantic Tag(s)
# Data Column
# order_id                Int64          Integer     ['numeric']
# product_id           category      Categorical    ['category']
# description            string  NaturalLanguage              []
# quantity                Int64          Integer     ['numeric']
# order_date     datetime64[ns]         Datetime              []
# unit_price            float64           Double     ['numeric']
# customer_name          string  NaturalLanguage              []
# country                string  NaturalLanguage              []
# total                 float64           Double     ['numeric']
# cancelled             boolean          Boolean              []

# %% [markdown]
# ## Set Initial DataTable Attributes

# %%
df.ww.init(time_index='order_date', 
           name='retail_data', 
           logical_types={'quantity':'Double'}, 
           make_index=True, 
           index='order_product_id')

# %%
df.ww.types
# Out:
#                    Physical Type     Logical Type Semantic Tag(s)
# Data Column
# order_product_id           Int64          Integer       ['index']
# order_id                   Int64          Integer     ['numeric']
# product_id              category      Categorical    ['category']
# description               string  NaturalLanguage              []
# quantity                 float64           Double     ['numeric']
# order_date        datetime64[ns]         Datetime  ['time_index']
# unit_price               float64           Double     ['numeric']
# customer_name             string  NaturalLanguage              []
# country                   string  NaturalLanguage              []
# total                    float64           Double     ['numeric']
# cancelled                boolean          Boolean              []

# %%
df = pd.read_csv('retail_data.csv', nrows=100)

# %% [markdown]
# ## Set Time Index

# %%
df = pd.read_csv('retail_data.csv', nrows=100)
df.ww.types
# Out:
#                 Physical Type     Logical Type Semantic Tag(s)
# Data Column
# order_id                Int64          Integer     ['numeric']
# product_id           category      Categorical    ['category']
# description            string  NaturalLanguage              []
# quantity                Int64          Integer     ['numeric']
# order_date     datetime64[ns]         Datetime              []
# unit_price            float64           Double     ['numeric']
# customer_name          string  NaturalLanguage              []
# country                string  NaturalLanguage              []
# total                 float64           Double     ['numeric']
# cancelled             boolean          Boolean              []

# %%
df.ww.init(name='retail_data', logical_types={'quantity':'Double'})
df.ww.dt = df.ww.set_time_index('order_date')
df.ww.types
# Out:
#                 Physical Type     Logical Type Semantic Tag(s)
# Data Column
# order_id                Int64          Integer     ['numeric']
# product_id           category      Categorical    ['category']
# description            string  NaturalLanguage              []
# quantity              float64           Double     ['numeric']
# order_date     datetime64[ns]         Datetime  ['time_index']
# unit_price            float64           Double     ['numeric']
# customer_name          string  NaturalLanguage              []
# country                string  NaturalLanguage              []
# total                 float64           Double     ['numeric']
# cancelled             boolean          Boolean              []

# %% [markdown]
# ## Set Semantic Tags

# %%
df = pd.read_csv('retail_data.csv', nrows=100)
df.ww.init(name='retail_data', logical_types={'quantity':'Double'})

# %%
df.ww.dt = df.ww.add_semantic_tags({'order_date': 'tag_1'})
df.ww.types
# Out:
#                 Physical Type     Logical Type Semantic Tag(s)
# Data Column
# order_id                Int64          Integer     ['numeric']
# product_id           category      Categorical    ['category']
# description            string  NaturalLanguage              []
# quantity              float64           Double     ['numeric']
# order_date     datetime64[ns]         Datetime       ['tag_1']
# unit_price            float64           Double     ['numeric']
# customer_name          string  NaturalLanguage              []
# country                string  NaturalLanguage              []
# total                 float64           Double     ['numeric']
# cancelled             boolean          Boolean              []

# %% [markdown]
# ## Select Based on Tags / Logical Types

# %%
df.ww.dt.select('tag_1')
# Out:
#               Physical Type Logical Type Semantic Tag(s)
# Data Column
# order_date   datetime64[ns]     Datetime       ['tag_1']

# %%
df.ww.dt.select(['Categorical', 'NaturalLanguage'])
# Out:
#               Physical Type     Logical Type Semantic Tag(s)
# Data Column
# product_id         category      Categorical    ['category']
# description          string  NaturalLanguage              []
# customer_name        string  NaturalLanguage              []
# country              string  NaturalLanguage              []

# %% [markdown]
# ## Select with normal iLoc

# %%
df.iloc[[0, 1]]
# Out:
#    order_id product_id                        description  quantity  \
# 0    536588      22666    RECIPE BOX PANTRY YELLOW DESIGN      12.0
# 1    536732      22910  PAPER CHAIN KIT VINTAGE CHRISTMAS       6.0
#
#            order_date  unit_price   customer_name         country   total  \
# 0 2010-12-01 16:49:00      4.8675  Emily Carrillo  United Kingdom  58.410
# 1 2010-12-02 12:47:00      4.8675      Tyler Rose  United Kingdom  29.205
#
#    cancelled
# 0      False
# 1      False

# %% [markdown]
# ## Serialization

# %%
df.ww.dt.to_csv('test')

# %%
import os
print(os.listdir('test'))
print(os.listdir('test/data'))
# Out:
# ['table_description.json', 'data']
# ['retail_data.csv']

# %% [markdown]
# ## Sample

# %%
df_sampled = df.sample(10)

# %%
df_sampled
# Out:
#     order_id product_id                         description  quantity  \
# 48    536404      22383             LUNCH BAG SUKI  DESIGN       10.0
# 76    536409      22075        6 RIBBONS ELEGANT CHRISTMAS        1.0
# 59    536532      22962               JAM JAR WITH PINK LID      12.0
# 73    536520      21584        RETROSPOT SMALL TUBE MATCHES      12.0
# 86    536531      21519     GIN & TONIC DIET GREETING CARD       24.0
# 77    536563      22964  3 PIECE SPACEBOY COOKIE CUTTER SET       4.0
# 41    536577      20725             LUNCH BAG RED RETROSPOT      60.0
# 67    536528      22634      CHILDS BREAKFAST SET SPACEBOY        1.0
# 53    536531      21497           FANCY FONTS BIRTHDAY WRAP      25.0
# 51    536370      22544                MINI JIGSAW SPACEBOY      24.0
#
#             order_date  unit_price      customer_name         country  \
# 48 2010-12-01 11:29:00      2.7225     William Chavez  United Kingdom
# 76 2010-12-01 11:45:00      2.7225  Gabriella Padilla  United Kingdom
# 59 2010-12-01 13:24:00      1.4025    Benjamin Glover          Norway
# 73 2010-12-01 12:43:00      2.7225    Taylor Marshall  United Kingdom
# 86 2010-12-01 13:23:00      0.6930      Jamie Vasquez  United Kingdom
# 77 2010-12-01 15:08:00      3.4650         Linda Gill  United Kingdom
# 41 2010-12-01 16:13:00      2.3925       Matthew Page  United Kingdom
# 67 2010-12-01 13:17:00     16.4175    Benjamin Bright  United Kingdom
# 53 2010-12-01 13:23:00      0.6930      Jamie Vasquez  United Kingdom
# 51 2010-12-01 08:45:00      0.6930  Micheal Nicholson          France
#
#        total  cancelled
# 48   27.2250      False
# 76    2.7225      False
# 59   16.8300      False
# 73   32.6700      False
# 86   16.6320      False
# 77   13.8600      False
# 41  143.5500      False
# 67   16.4175      False
# 53   17.3250      False
# 51   16.6320      False

# %%
df_sampled.ww.dt.select(['Categorical'])
# Out:
#             Physical Type Logical Type Semantic Tag(s)
# Data Column
# product_id       category  Categorical    ['category']

# %%
df_sampled.dtypes
# Out:
# order_id                  Int64
# product_id             category
# description              string
# quantity                float64
# order_date       datetime64[ns]
# unit_price              float64
# customer_name            string
# country                  string
# total                   float64
# cancelled               boolean
# dtype: object

# %%
df_sampled.ww.types
# Out:
#                 Physical Type     Logical Type Semantic Tag(s)
# Data Column
# order_id                Int64          Integer     ['numeric']
# product_id           category      Categorical    ['category']
# description            string  NaturalLanguage              []
# quantity              float64           Double     ['numeric']
# order_date     datetime64[ns]         Datetime              []
# unit_price            float64           Double     ['numeric']
# customer_name          string  NaturalLanguage              []
# country                string  NaturalLanguage              []
# total                 float64           Double     ['numeric']
# cancelled             boolean          Boolean              []

# %% [markdown]
# # To Do - Add Util Functions

# %% [markdown]
# ### Describe
#
# ```python
# def describe(dataframe)
#     """
#         dataframe (pd.DataFrame): DataFrame with woodwork init
#     """
# ```

# %% [markdown]
# ### End user for Describe
#
# ```python
# from woodwork import describe
#
# dataframe_described = describe(df)
# ```
